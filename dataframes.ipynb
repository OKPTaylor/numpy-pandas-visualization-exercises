# %%
import pandas as pd 
import numpy as np


from pydataset import data

# %%
np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
#1.a and b

# %%
df["passing_english"] = df["english"] <=69

df.sort_values('passing_english')
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80            False
# 1      Jane    88       79       67            False
# 2     Suzie    94       74       95            False
# 3     Billy    98       96       88            False
# 4       Ada    77       92       98            False
# 5      John    79       76       93            False
# 6    Thomas    82       64       81             True
# 7     Marie    93       63       90             True
# 8    Albert    92       62       87             True
# 9   Richard    69       80       94            False
# 10    Isaac    92       99       93            False
# 11     Alan    92       62       72             True

# %%
# seems to break duplicates of sorted by sorting again by the value the sorted by column is based?

# %%
#1.c

# %%
df.assign(passing_english = df["english"] <=69).sort_values("name").sort_values("passing_english")
# Out:
#        name  math  english  reading  passing_english
# 4       Ada    77       92       98            False
# 3     Billy    98       96       88            False
# 10    Isaac    92       99       93            False
# 1      Jane    88       79       67            False
# 5      John    79       76       93            False
# 9   Richard    69       80       94            False
# 0     Sally    62       85       80            False
# 2     Suzie    94       74       95            False
# 11     Alan    92       62       72             True
# 8    Albert    92       62       87             True
# 7     Marie    93       63       90             True
# 6    Thomas    82       64       81             True

# %%
#1.d

# %%
df.assign(passing_english = df["english"] <=69).sort_values("english").sort_values("passing_english")

#better way to do it: df.sort_values()
# Out:
#        name  math  english  reading  passing_english
# 2     Suzie    94       74       95            False
# 5      John    79       76       93            False
# 1      Jane    88       79       67            False
# 9   Richard    69       80       94            False
# 0     Sally    62       85       80            False
# 4       Ada    77       92       98            False
# 3     Billy    98       96       88            False
# 10    Isaac    92       99       93            False
# 8    Albert    92       62       87             True
# 11     Alan    92       62       72             True
# 7     Marie    93       63       90             True
# 6    Thomas    82       64       81             True

# %%
#1.e

# %%
df.assign(overallgrade = (df["english"] + df["math"] + df["reading"])/3)

#better way to do it df[new_column_name] = (df.column_name + df.column_name2 + df.column_name3) / 3
# Out:
#        name  math  english  reading  overallgrade
# 0     Sally    62       85       80     75.666667
# 1      Jane    88       79       67     78.000000
# 2     Suzie    94       74       95     87.666667
# 3     Billy    98       96       88     94.000000
# 4       Ada    77       92       98     89.000000
# 5      John    79       76       93     82.666667
# 6    Thomas    82       64       81     75.666667
# 7     Marie    93       63       90     82.000000
# 8    Albert    92       62       87     80.333333
# 9   Richard    69       80       94     81.000000
# 10    Isaac    92       99       93     94.666667
# 11     Alan    92       62       72     75.333333

# %%
#2

# %%
mpg = data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
#a

# %%
mpg.shape
# Out:
# (234, 11)

# %%
#234 rows 11 columns

# %%
#b and c

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
#c

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.assign()

# %%
#d and e

# %%
mpg.rename(columns={"cty" : "city" , "hwy":"highway", "class" : "class_of_vehicle"}, inplace=True)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     class_of_vehicle
# 1            compact
# ...

# %%
#f

# %%
mpg.assign(better_city_than_highway = mpg["city"] > mpg['highway']).sort_values(by = "better_city_than_highway", ascending=False)
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  city  \
# 1           audi               a4    1.8  1999    4    auto(l5)   f    18
# 161       subaru     forester awd    2.5  1999    4    auto(l4)   4    18
# 149       nissan           maxima    3.0  1999    6  manual(m5)   f    19
# 150       nissan           maxima    3.5  2008    6    auto(av)   f    19
# 151       nissan   pathfinder 4wd    3.3  1999    6    auto(l4)   4    14
# ..           ...              ...    ...   ...  ...         ...  ..   ...
# 83          ford     explorer 4wd    5.0  1999    8    auto(l4)   4    13
# 84          ford  f150 pickup 4wd    4.2  1999    6    auto(l4)   4    14
# 85          ford  f150 pickup 4wd    4.2  1999    6  manual(m5)   4    14
# 86          ford  f150 pickup 4wd    4.6  1999    8  manual(m5)   4    13
# 234   volkswagen           passat    3.6  2008    6    auto(s6)   f    17
#
#      highway fl class_of_vehicle  better_city_than_highway
# ...

# %%
#better
mpg[mpg.city > mpg.highway]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class_of_vehicle]
# Index: []

# %%
#no

# %%
mpg.assign(mileage_difference = mpg["highway"] - mpg['city'])
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# ...

# %%
#g

# %%
mpg.assign(mileage_difference = mpg["highway"] - mpg['city']).sort_values("mileage_difference", ascending=False)
#mpg[mpg.mileage_difference == mpg.mileage_difference.max()]
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 107        honda              civic    1.8  2008    4    auto(l5)   f    24
# 223   volkswagen         new beetle    1.9  1999    4    auto(l4)   f    29
# 1           audi                 a4    1.8  1999    4    auto(l5)   f    18
# 229   volkswagen             passat    1.8  1999    4    auto(l5)   f    18
# 36     chevrolet             malibu    3.5  2008    6    auto(l4)   f    18
# ..           ...                ...    ...   ...  ...         ...  ..   ...
# 80          ford       explorer 4wd    4.0  1999    6    auto(l5)   4    14
# 138      mercury    mountaineer 4wd    4.0  1999    6    auto(l5)   4    14
# 177       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4    15
# 152       nissan     pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 204       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
#
#      highway fl       class  mileage_difference
# ...

# %%
#h

# %%
mpg[mpg.class_of_vehicle == "compact"].sort_values("highway").min()
# Out:
# manufacturer            audi
# model                     a4
# displ                    1.8
# year                    1999
# cyl                        4
# trans               auto(av)
# drv                        4
# city                      15
# highway                   23
# fl                         d
# class_of_vehicle     compact
# dtype: object

# %%
mpg[mpg.class_of_vehicle == "compact"].sort_values("highway").max()
# Out:
# manufacturer        volkswagen
# model                    jetta
# displ                      3.3
# year                      2008
# cyl                          6
# trans               manual(m6)
# drv                          f
# city                        33
# highway                     44
# fl                           r
# class_of_vehicle       compact
# dtype: object

# %%
#i

# %%
mpg_avg = mpg.assign(average_mileage = (mpg["highway"] + mpg['city']) / 2)
mpg_avg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     class_of_vehicle  average_mileage
# ...

# %%
#j

# %%
mpg_avg[mpg.manufacturer == "dodge"].sort_values("average_mileage").max()
# Out:
# manufacturer                      dodge
# model               ram 1500 pickup 4wd
# displ                               5.9
# year                               2008
# cyl                                   8
# trans                        manual(m6)
# drv                                   f
# city                                 18
# highway                              24
# fl                                    r
# class_of_vehicle                    suv
# average_mileage                    21.0
# dtype: object

# %%
mpg_avg[mpg.manufacturer == "dodge"].sort_values("average_mileage").min()
# Out:
# manufacturer              dodge
# model               caravan 2wd
# displ                       2.4
# year                       1999
# cyl                           4
# trans                  auto(l3)
# drv                           4
# city                          9
# highway                      12
# fl                            e
# class_of_vehicle        minivan
# average_mileage            10.5
# dtype: object
