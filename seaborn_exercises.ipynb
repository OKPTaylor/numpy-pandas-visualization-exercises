# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from pydataset import data
import env

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.petal_length.value_counts()
# Out:
# 1.5    13
# 1.4    13
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.0     5
# 4.9     5
# 4.7     5
# 5.0     4
# 1.7     4
# 4.8     4
# 4.4     4
# 4.2     4
# 4.1     3
# 5.7     3
# 5.5     3
# 6.1     3
# 3.9     3
# 4.6     3
# 5.8     3
# 5.2     2
# 1.9     2
# 6.0     2
# 1.2     2
# 4.3     2
# 5.3     2
# 5.4     2
# 3.3     2
# 6.7     2
# 3.5     2
# 5.9     2
# 3.6     1
# 3.8     1
# 1.0     1
# 3.0     1
# 6.3     1
# 6.6     1
# 3.7     1
# 1.1     1
# 6.4     1
# 6.9     1
# Name: petal_length, dtype: int64

# %%
#1
sns.displot(data=iris, x='petal_length')
plt.show()

# %%
#2
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), cmap="Reds", annot=True)
plt.show()

# scatter plot would also show how there is a relationship
#yes

# %%
#3

# %%
sns.pairplot(data=iris, corner=True, hue="species")

# %%
#not the best

# %%
sns.pairplot(data=iris, corner=True, hue="species")

# %%
# petal length and width

# %%
#2.1   
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
anscombe = sns.load_dataset('anscombe')
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
sns.relplot(data=anscombe, x="x", y="y", hue="dataset")
plt.show()

# %%
#2.2
from pydataset import data
insect_sprays= data("InsectSprays")

# %%
data("InsectSprays", show_doc=True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
# ...

# %%
insect_sprays.value_counts()
# Out:
# count  spray
# 5      D        5
# 3      E        4
# 1      C        4
# 17     B        3
# 14     A        3
# 0      C        2
# 6      E        2
# 21     B        2
# 20     A        2
# 15     F        2
# 13     F        2
# 11     B        2
# 10     A        2
# 26     F        2
# 3      D        2
# 1      E        2
# 2      C        2
# 4      D        2
# 5      E        2
# 3      C        2
# 14     B        1
# 24     F        1
# 23     A        1
# 22     F        1
# 19     B        1
# 2      D        1
# 17     A        1
# 16     F        1
#        B        1
# 2      E        1
# 6      D        1
# 13     B        1
#        A        1
# 12     D        1
#        A        1
# 11     F        1
# 4      C        1
#        E        1
# 9      F        1
# 7      C        1
#        B        1
#        A        1
# 10     F        1
# dtype: int64

# %%
sns.catplot(data=insect_sprays, x="spray", y="count" , kind="box")

# %%
#3
swiss = data("swiss")
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
swiss["is_catholic"] = swiss.Catholic > 50

# %%
sns.boxplot(data=swiss, x="is_catholic", y="Fertility")
plt.show()

# %%
swiss.corr()
# Out:
#                   Fertility  Agriculture  Examination  Education  Catholic  \
# Fertility          1.000000     0.353079    -0.645883  -0.663789  0.463685
# Agriculture        0.353079     1.000000    -0.686542  -0.639523  0.401095
# Examination       -0.645883    -0.686542     1.000000   0.698415 -0.572742
# Education         -0.663789    -0.639523     0.698415   1.000000 -0.153859
# Catholic           0.463685     0.401095    -0.572742  -0.153859  1.000000
# Infant.Mortality   0.416556    -0.060859    -0.114022  -0.099322  0.175496
# is_catholic        0.402813     0.410503    -0.597861  -0.154677  0.961723
#
#                   Infant.Mortality  is_catholic
# Fertility                 0.416556     0.402813
# Agriculture              -0.060859     0.410503
# Examination              -0.114022    -0.597861
# Education                -0.099322    -0.154677
# Catholic                  0.175496     0.961723
# Infant.Mortality          1.000000     0.166081
# ...

# %%
sns.heatmap(swiss.corr(), annot=True, cmap="Blues")
plt.show()

# %%
for col in swiss:
    sns.scatterplot(data=swiss, y="Fertility", x=col) #loop and plot
    plt.show()

# %%
#4

# %%
def get_db_url(data_base):
    return (f'mysql+pymysql://{env.username}:{env.password}@{env.host}/{data_base}')

# %%
orders = pd.read_sql("select * from orders", get_db_url("chipotle"))

# %%
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
popular_items = orders[["item_name" ,"quantity" , "item_price"]]

popular_items.item_price = popular_items.item_price.str.strip('$').astype(float)

popular_items
# Out:
# /Users/olivertaylor/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                                   item_name  quantity  item_price
# 0              Chips and Fresh Tomato Salsa         1        2.39
# 1                                      Izze         1        3.39
# 2                          Nantucket Nectar         1        3.39
# 3     Chips and Tomatillo-Green Chili Salsa         1        2.39
# 4                              Chicken Bowl         2       16.98
# ...                                     ...       ...         ...
# 4617                          Steak Burrito         1       11.75
# ...

# %%
popular_items.groupby("item_name", as_index=False)[["item_price"]].sum().sort_values("item_price", ascending=False).head(4)
# Out:
#           item_name  item_price
# 17     Chicken Bowl     7342.73
# 18  Chicken Burrito     5575.82
# 39    Steak Burrito     3851.43
# 38       Steak Bowl     2260.19

# %%
sns.catplot(data=popular_items.groupby("item_name", as_index=False)[["item_price"]].sum().sort_values("item_price", ascending=False).head(4), x="item_name",  y="item_price" ,kind="bar")
plt.show()

# %%
#5

# %%
sleep = data("sleepstudy")
sleep.head()
# Out:
#    Reaction  Days  Subject
# 1  249.5600     0      308
# 2  258.7047     1      308
# 3  250.8006     2      308
# 4  321.4398     3      308
# 5  356.8519     4      308

# %%
sleep.dtypes
# Out:
# Reaction    float64
# Days          int64
# Subject       int64
# dtype: object

# %%
plt.figure(figsize= (12, 6))
sns.lineplot(data=sleep, x="Days", y="Reaction", hue="Subject", palette="Accent")
plt.title("Sleep Study Subject Reaction Times")
plt.legend(loc="upper right")
plt.show()

# %%
#palette = asccents
