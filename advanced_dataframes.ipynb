# %%
import pandas as pd
import numpy as  np

# %%
from pydataset import data

# %%
import env

# %%
def get_db_url(data_base):
    return (f'mysql+pymysql://{env.username}:{env.password}@{env.host}/{data_base}')

# %%
#get_db_url(env.username, env.host, env.password, "employees")

# %%
#get_db_url = f'mysql+pymysql://{env.username}:{env.password}@{env.host}/employees'

# %%
employees = pd.read_sql("select * from employees", get_db_url("employees"))

# %%
titles = pd.read_sql("select * from titles", get_db_url("employees"))

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
titles.title.value_counts()
# Out:
# Engineer              115003
# Staff                 107391
# Senior Engineer        97750
# Senior Staff           92853
# Technique Leader       15159
# Assistant Engineer     15128
# Manager                   24
# Name: title, dtype: int64

# %%
#or 
len(titles.title.unique())
# Out:
# 7

# %%
titles.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %%
titles[titles.to_date != titles.to_date.max()].to_date.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 3         1995-12-01
# 6         1996-09-12
# 9         1996-02-11
# 10        2000-07-31
# 11        1990-02-18
#              ...
# 443297    1992-05-09
# 443299    1993-10-27
# 443301    2002-05-13
# 443303    1992-08-29
# 443306    1998-12-27
# Name: to_date, Length: 203184, dtype: object>

# %%
#part 2

# %%
#1

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
#2

# %%
pd.merge(users,roles, how='right', left_on='role_id', right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %%
#3

# %%
pd.merge(users,roles, how='outer', left_on='role_id', right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %%
#4

# %%
#it doesn't work

# %%
#5

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
#6

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
#7

# %%
mpg.shape
# Out:
# (234, 11)

# %%
#8

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
#9

# %%
mpg.describe()
#or can use .describe(include="all")
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#10

# %%
len(mpg.manufacturer.unique())
# Out:
# 15

# %%
#11

# %%
len(mpg['model'].unique())
# Out:
# 38

# %%
#12

# %%
mpg['mileage_difference'] = mpg["hwy"] - mpg['cty']
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# ...

# %%
#13

# %%
mpg["average_mileage"] = (mpg["hwy"] + mpg['cty']) / 2

mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage
# 1    compact                  11             23.5
# ...

# %%
#14

# %%
mpg.trans.value_counts()
# Out:
# auto(l4)      83
# manual(m5)    58
# auto(l5)      39
# manual(m6)    19
# auto(s6)      16
# auto(l6)       6
# auto(av)       5
# auto(s4)       3
# auto(s5)       3
# auto(l3)       2
# Name: trans, dtype: int64

# %%
mpg['is_automatic']=mpg.trans.str.contains("auto")

mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage  is_automatic
# ...

# %%
#15

# %%
mpg.groupby('manufacturer').mean().average_mileage.sort_values(ascending=False)
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000
# Name: average_mileage, dtype: float64

# %%
#16

# %%
mpg.groupby("is_automatic").mean().average_mileage
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %%
#part 3

# %%
#1

# %%
orders = pd.read_sql("select * from orders", get_db_url("chipotle"))

# %%
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
#2

# %%
orders.item_price = orders.item_price.str.strip("$").astype(float)

# %%
orders.groupby('order_id').item_price.sum().head()
#pd.crosstab(orders.order_id, orders.item_price)
# Out:
# order_id
# 1    11.56
# 2    16.98
# 3    12.67
# 4    21.00
# 5    13.70
# Name: item_price, dtype: float64

# %%
#3

# %%
orders.groupby("item_name").quantity.sum().sort_values(ascending=False).head()
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
#4

# %%
orders.groupby("item_name").item_price.sum().sort_values(ascending=False).head() #can also use nlargest(int_of_top_to_return)
# Out:
# item_name
# Carnitas Soft Tacos      9.25 9.25 9.25 9.25 9.25 8.99 8.99 8.99 9.25 9.25 9.25 9.25 9.25 9.25 9.25 11.75 9.25 ...
# Barbacoa Soft Tacos      9.25 9.25 8.99 9.25 9.25 11.75 11.75 9.25 9.25 11.75 9.25 8.99 9.25 11.75 9.25 9.25 9....
# Steak Soft Tacos         9.25 9.25 8.99 9.25 8.99 8.99 9.25 9.25 8.99 9.25 8.99 9.25 9.25 9.25 9.25 8.99 9.25 1...
# Steak Crispy Tacos       9.25 8.99 9.25 8.69 8.99 9.25 8.99 9.25 8.99 8.99 9.25 9.25 11.75 8.99 11.75 11.75 11....
# Carnitas Crispy Tacos                                                       9.25 11.75 8.99 11.75 8.99 17.98 9.25
# Name: item_price, dtype: object

# %%
#5

# %%
employees = pd.read_sql("select * from employees", get_db_url("employees"))
titles = pd.read_sql("select * from titles", get_db_url("employees"))

# %%
joined_data= pd.merge(employees, titles, how = 'inner', on="emp_no")
joined_data
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %%
#6

# %%
joined_data.groupby("title").hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %%
#7

# %%
departments = pd.read_sql("select * from departments", get_db_url("employees"))

# %%
dept_emp = pd.read_sql("select emp_no, dept_no from dept_emp", get_db_url("employees"))
dept_emp
# Out:
#         emp_no dept_no
# 0        10017    d001
# 1        10055    d001
# 2        10058    d001
# 3        10108    d001
# 4        10140    d001
# ...        ...     ...
# 331598  499965    d009
# 331599  499978    d009
# 331600  499982    d009
# 331601  499983    d009
# 331602  499991    d009
#
# [331603 rows x 2 columns]

# %%
joined_data= pd.merge(joined_data, dept_emp, how = 'inner', on="emp_no")

joined_data
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 489898  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 489899  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 489900  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 489901  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 489902  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date dept_no
# 0       Senior Engineer  1986-06-26  9999-01-01    d005
# ...

# %%
joined_data = pd.merge(joined_data, departments, how = 'inner', on="dept_no")

joined_data
# Out:
#         emp_no  birth_date first_name  last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi    Facello      M  1986-06-26
# 1        10006  1953-04-20     Anneke    Preusig      F  1989-06-02
# 2        10008  1958-02-19     Saniya   Kalloufi      M  1994-09-15
# 3        10012  1960-10-04   Patricio  Bridgland      M  1992-12-18
# 4        10012  1960-10-04   Patricio  Bridgland      M  1992-12-18
# ...        ...         ...        ...        ...    ...         ...
# 489898  499975  1952-11-09     Masali    Chorvat      M  1992-01-23
# 489899  499977  1956-06-05    Martial    Weisert      F  1996-09-17
# 489900  499989  1954-05-26  Keiichiro  Lindqvist      M  1993-10-28
# 489901  499998  1956-09-05   Patricia    Breugel      M  1993-10-13
# 489902  499998  1956-09-05   Patricia    Breugel      M  1993-10-13
#
#                      title   from_date     to_date dept_no    dept_name
# 0          Senior Engineer  1986-06-26  9999-01-01    d005  Development
# ...

# %%
crosstab_of_depart = pd.crosstab(joined_data.title, joined_data.dept_name)
crosstab_of_depart
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        6445                1831       378      0
# Engineer                    0       49649               13852      2986      0
# Manager                     2           4                   4         2      2
# ...
